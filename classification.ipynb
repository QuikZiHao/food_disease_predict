# %%
import pandas as pd


df = pd.read_csv("data/final_data.csv",encoding="utf-8-sig")
df
# Out:
#           患者ID 是否复诊 是否住院 患者性别  患者年龄 现在住址地市        发病日期      食品分类     加工及包装方式  \
# 0            1    否    否    女  27.0    嘉兴市   5/17/2022  水产动物及其制品       餐饮服务业
# 1            1    否    否    女  27.0    嘉兴市   5/17/2022  水产动物及其制品       餐饮服务业
# 2            1    否    否    女  27.0    嘉兴市   5/17/2022  水产动物及其制品       餐饮服务业
# 3            2    否    否    男  63.0    金华市  10/17/2023     肉与肉制品        家庭自制
# 4            3    否    否    女  22.0    温州市   6/10/2021     肉与肉制品       餐饮服务业
# ...        ...  ...  ...  ...   ...    ...         ...       ...         ...
# 564432  177055    否    否    男  26.0    衢州市   10/4/2022     乳与乳制品         预包装
# 564433  177056    否    否    女  40.0    丽水市   12/7/2022  水产动物及其制品          其他
# 564434  177057    否    否    男  49.0    丽水市  11/28/2022     乳与乳制品         预包装
# 564435  177058    否    否    男   4.0    丽水市  11/21/2022     蛋与蛋制品        家庭自制
# 564436  177059    否    否    男  60.0    丽水市  11/28/2022  水产动物及其制品  散装（包括简易包装）
#
#        进食场所类型  ...  降水量 Temperature-before1day Temperature-before2day  \
# 0          其他  ...  0.0              19.450859              17.325065
# 1          其他  ...  0.0              19.450859              17.325065
# 2          其他  ...  0.0              19.450859              17.325065
# 3          家庭  ...  0.0              19.142827              19.428568
# 4          其他  ...  0.0              27.192274              26.011637
# ...       ...  ...  ...                    ...                    ...
# 564432     其他  ...  0.0              30.662027              29.871408
# 564433     家庭  ...  0.0               9.363357               7.801326
# 564434     家庭  ...  0.0              15.614301              18.837044
# 564435     家庭  ...  0.0              18.575637              18.250390
# 564436     家庭  ...  0.0              15.614301              18.837044
#
#         Temperature-before3day  Temperature-before4day  \
# 0                    18.022912               15.695780
# 1                    18.022912               15.695780
# 2                    18.022912               15.695780
# 3                    19.022599               19.634189
# 4                    24.449164               23.106728
# ...                        ...                     ...
# 564432               30.030178               28.689977
# 564433                9.298979                9.127577
# 564434               17.907945               17.521483
# 564435               18.142675               18.915936
# 564436               17.907945               17.521483
#
#         Temperature-before5day  Temperature-before6day  \
# 0                    17.872882               18.802054
# 1                    17.872882               18.802054
# 2                    17.872882               18.802054
# 3                    20.866985               18.601098
# 4                    20.481727               20.071709
# ...                        ...                     ...
# 564432               26.203724               26.658370
# 564433                5.589593                3.819305
# 564434               16.843170               18.156055
# 564435               17.311793               14.466131
# 564436               16.843170               18.156055
#
#         Temperature-before7day       阳光数据    AQI
# 0                    18.796211   0.000000  117.0
# 1                    18.796211   0.000000  117.0
# 2                    18.796211   0.000000  117.0
# 3                    18.851912  28.397667  103.0
# 4                    27.021025   0.073370   30.0
# ...                        ...        ...    ...
# 564432               26.244053   1.192956   92.0
# 564433                5.596960   0.000000   43.0
# 564434               19.529726   0.852412   44.0
# 564435               15.251207   1.055904   39.0
# 564436               19.529726   0.852412   44.0
#
# [564437 rows x 37 columns]

# %%
from src.implement.xgboost_impl_classification import solve_data
df = solve_data(df)
df
# Out:
# c:\Users\AORUS\Desktop\program\food_disease_predict\src\implement\xgboost_impl_classification.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["鉴定结果大类"].fillna("/", inplace=True)
#           患者ID  患者性别  患者年龄  其他人是否发病  气候政策不确定性指数  环保处罚案件数目  经济核算-生产总值（亿元）  \
# 0            1     0  27.0        0    0.771001     605.0        6739.00
# 1            1     0  27.0        0    0.771001     605.0        6739.00
# 2            1     0  27.0        0    0.771001     605.0        6739.00
# 4            3     0  22.0        1    2.030405     465.0        7585.02
# 5            3     0  22.0        1    2.030405     465.0        7585.02
# ...        ...   ...   ...      ...         ...       ...            ...
# 564432  177055     1  26.0        0    0.617790     168.0        2003.00
# 564433  177056     0  40.0        0    0.858528     182.0        1831.00
# 564434  177057     1  49.0        0    0.371667     182.0        1831.00
# 564435  177058     1   4.0        0    0.371667     182.0        1831.00
# 564436  177059     1  60.0        0    0.371667     182.0        1831.00
#
#         农业-农、林、牧、渔业总产值（亿元）  农业-主要农产品产量-肉产量（吨）  农业-主要农产品产量-禽蛋产量（吨）  ...  \
# 0                   235.91            90329.0             27084.0  ...
# 1                   235.91            90329.0             27084.0  ...
# 2                   235.91            90329.0             27084.0  ...
# 4                   260.65           106238.0             26168.0  ...
# 5                   260.65           106238.0             26168.0  ...
# ...                    ...                ...                 ...  ...
# 564432              148.02           178857.0             48975.0  ...
# 564433              169.86            72357.0             12687.0  ...
# 564434              169.86            72357.0             12687.0  ...
# 564435              169.86            72357.0             12687.0  ...
# 564436              169.86            72357.0             12687.0  ...
#
#         加工及包装方式_散装（包括简易包装）  加工及包装方式_预包装  加工及包装方式_餐饮服务业  进食场所类型_农村宴席  \
# 0                    False        False           True        False
# 1                    False        False           True        False
# 2                    False        False           True        False
# 4                    False        False           True        False
# 5                     True        False          False        False
# ...                    ...          ...            ...          ...
# 564432               False         True          False        False
# 564433               False        False          False        False
# 564434               False         True          False        False
# 564435               False        False          False        False
# 564436                True        False          False        False
#
#         进食场所类型_学校  进食场所类型_家庭  进食场所类型_集体食堂  进食场所类型_零售市场  进食场所类型_餐饮服务业  发病月份
# 0           False      False        False        False         False     5
# 1           False      False        False        False         False     5
# 2           False      False        False        False         False     5
# 4           False      False        False        False         False     6
# 5           False      False        False        False         False     6
# ...           ...        ...          ...          ...           ...   ...
# 564432      False      False        False        False         False    10
# 564433      False       True        False        False         False    12
# 564434      False       True        False        False         False    11
# 564435      False       True        False        False         False    11
# 564436      False       True        False        False         False    11
#
# [482897 rows x 44 columns]

# %%
df.keys()
# Out:
# Index([' 患者ID', '患者性别', '患者年龄', '其他人是否发病', '气候政策不确定性指数', '环保处罚案件数目',
#        '经济核算-生产总值（亿元）', '农业-农、林、牧、渔业总产值（亿元）', '农业-主要农产品产量-肉产量（吨）',
#        '农业-主要农产品产量-禽蛋产量（吨）', '农业-主要农产品产量-牛奶产量（吨）', '农业-水产品产量（万吨）',
#        '农业-农村能源及农业物资消耗-农用塑料薄膜使用量（吨）', '农业-农村能源及农业物资消耗-农用柴油使用量（吨）',
#        '农业-农村能源及农业物资消耗-农用化肥施用量（折纯）（吨）', '农业-农村能源及农业物资消耗-农药使用量（吨）',
#        '文化、卫生和社会服务-文化和卫生-医院卫生院数（个）', '文化、卫生和社会服务-文化和卫生-医生数（人）', '降水量',
#        'Temperature-before1day', 'Temperature-before2day',
#        'Temperature-before3day', 'Temperature-before4day',
#        'Temperature-before5day', 'Temperature-before6day',
#        'Temperature-before7day', '阳光数据', 'AQI', '确诊食源性疾病', '食品分类_水产动物及其制品',
#        '食品分类_油脂类', '食品分类_肉与肉制品', '食品分类_蛋与蛋制品', '加工及包装方式_家庭自制',
#        '加工及包装方式_散装（包括简易包装）', '加工及包装方式_预包装', '加工及包装方式_餐饮服务业', '进食场所类型_农村宴席',
#        '进食场所类型_学校', '进食场所类型_家庭', '进食场所类型_集体食堂', '进食场所类型_零售市场', '进食场所类型_餐饮服务业',
#        '发病月份'],
#       dtype='object')

# %% [markdown]
# # by case

# %%
from src.implement.xgboost_impl_classification import to_dataset,train
df = df.drop(columns=[' 患者ID'])

X_train, X_test, y_train, y_test = to_dataset(df)

model = train(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\AORUS\Desktop\program\food_disease_predict\fooddisease\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:21:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.8849658314350797
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94     93243
#            1       0.07      0.20      0.11      3337
#
#     accuracy                           0.88     96580
#    macro avg       0.52      0.55      0.52     96580
# weighted avg       0.94      0.88      0.91     96580

# %%
from src.implement.xgboost_impl_classification import get_importance,plot_heap,plot_roc_auc

get_importance(model)
plot_heap(X_test, y_test,model)
plot_roc_auc(X_test, y_test,model)

# %% [markdown]
# # by human

# %%
from src.implement.xgboost_impl_classification import solve_data
df = pd.read_csv("data/final_data.csv",encoding="utf-8-sig")
df = solve_data(df)
df
# Out:
# c:\Users\AORUS\Desktop\program\food_disease_predict\src\implement\xgboost_impl_classification.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["鉴定结果大类"].fillna("/", inplace=True)
#           患者ID  患者性别  患者年龄  其他人是否发病  气候政策不确定性指数  环保处罚案件数目  经济核算-生产总值（亿元）  \
# 0            1     0  27.0        0    0.771001     605.0        6739.00
# 1            1     0  27.0        0    0.771001     605.0        6739.00
# 2            1     0  27.0        0    0.771001     605.0        6739.00
# 4            3     0  22.0        1    2.030405     465.0        7585.02
# 5            3     0  22.0        1    2.030405     465.0        7585.02
# ...        ...   ...   ...      ...         ...       ...            ...
# 564432  177055     1  26.0        0    0.617790     168.0        2003.00
# 564433  177056     0  40.0        0    0.858528     182.0        1831.00
# 564434  177057     1  49.0        0    0.371667     182.0        1831.00
# 564435  177058     1   4.0        0    0.371667     182.0        1831.00
# 564436  177059     1  60.0        0    0.371667     182.0        1831.00
#
#         农业-农、林、牧、渔业总产值（亿元）  农业-主要农产品产量-肉产量（吨）  农业-主要农产品产量-禽蛋产量（吨）  ...  \
# 0                   235.91            90329.0             27084.0  ...
# 1                   235.91            90329.0             27084.0  ...
# 2                   235.91            90329.0             27084.0  ...
# 4                   260.65           106238.0             26168.0  ...
# 5                   260.65           106238.0             26168.0  ...
# ...                    ...                ...                 ...  ...
# 564432              148.02           178857.0             48975.0  ...
# 564433              169.86            72357.0             12687.0  ...
# 564434              169.86            72357.0             12687.0  ...
# 564435              169.86            72357.0             12687.0  ...
# 564436              169.86            72357.0             12687.0  ...
#
#         加工及包装方式_散装（包括简易包装）  加工及包装方式_预包装  加工及包装方式_餐饮服务业  进食场所类型_农村宴席  \
# 0                    False        False           True        False
# 1                    False        False           True        False
# 2                    False        False           True        False
# 4                    False        False           True        False
# 5                     True        False          False        False
# ...                    ...          ...            ...          ...
# 564432               False         True          False        False
# 564433               False        False          False        False
# 564434               False         True          False        False
# 564435               False        False          False        False
# 564436                True        False          False        False
#
#         进食场所类型_学校  进食场所类型_家庭  进食场所类型_集体食堂  进食场所类型_零售市场  进食场所类型_餐饮服务业  发病月份
# 0           False      False        False        False         False     5
# 1           False      False        False        False         False     5
# 2           False      False        False        False         False     5
# 4           False      False        False        False         False     6
# 5           False      False        False        False         False     6
# ...           ...        ...          ...          ...           ...   ...
# 564432      False      False        False        False         False    10
# 564433      False       True        False        False         False    12
# 564434      False       True        False        False         False    11
# 564435      False       True        False        False         False    11
# 564436      False       True        False        False         False    11
#
# [482897 rows x 44 columns]

# %%
df.keys()
# Out:
# Index([' 患者ID', '患者性别', '患者年龄', '其他人是否发病', '气候政策不确定性指数', '环保处罚案件数目',
#        '经济核算-生产总值（亿元）', '农业-农、林、牧、渔业总产值（亿元）', '农业-主要农产品产量-肉产量（吨）',
#        '农业-主要农产品产量-禽蛋产量（吨）', '农业-主要农产品产量-牛奶产量（吨）', '农业-水产品产量（万吨）',
#        '农业-农村能源及农业物资消耗-农用塑料薄膜使用量（吨）', '农业-农村能源及农业物资消耗-农用柴油使用量（吨）',
#        '农业-农村能源及农业物资消耗-农用化肥施用量（折纯）（吨）', '农业-农村能源及农业物资消耗-农药使用量（吨）',
#        '文化、卫生和社会服务-文化和卫生-医院卫生院数（个）', '文化、卫生和社会服务-文化和卫生-医生数（人）', '降水量',
#        'Temperature-before1day', 'Temperature-before2day',
#        'Temperature-before3day', 'Temperature-before4day',
#        'Temperature-before5day', 'Temperature-before6day',
#        'Temperature-before7day', '阳光数据', 'AQI', '确诊食源性疾病', '食品分类_水产动物及其制品',
#        '食品分类_油脂类', '食品分类_肉与肉制品', '食品分类_蛋与蛋制品', '加工及包装方式_家庭自制',
#        '加工及包装方式_散装（包括简易包装）', '加工及包装方式_预包装', '加工及包装方式_餐饮服务业', '进食场所类型_农村宴席',
#        '进食场所类型_学校', '进食场所类型_家庭', '进食场所类型_集体食堂', '进食场所类型_零售市场', '进食场所类型_餐饮服务业',
#        '发病月份'],
#       dtype='object')

# %%
df = df.sort_values("确诊食源性疾病",ascending=False)
df = df.drop_duplicates(subset=" 患者ID", keep="first")

# %%
from src.implement.xgboost_impl_classification import to_dataset,train
df = df.drop(columns=[' 患者ID'])

X_train, X_test, y_train, y_test = to_dataset(df)

model = train(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\AORUS\Desktop\program\food_disease_predict\fooddisease\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:22:05] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.8321917808219178
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91     26947
#            1       0.24      0.29      0.26      3129
#
#     accuracy                           0.83     30076
#    macro avg       0.58      0.59      0.58     30076
# weighted avg       0.85      0.83      0.84     30076

# %%
from src.implement.xgboost_impl_classification import get_importance,plot_heap,plot_roc_auc

get_importance(model)
plot_heap(X_test, y_test,model)
plot_roc_auc(X_test, y_test,model)
