# %%
import pandas as pd


df = pd.read_csv("data/final_data.csv",encoding="utf-8-sig")
df
# Out:
#           患者ID 是否复诊 是否住院 患者性别  患者年龄 现在住址地市        发病日期      食品分类     加工及包装方式  \
# 0            1    否    否    女  27.0    嘉兴市   5/17/2022  水产动物及其制品       餐饮服务业
# 1            1    否    否    女  27.0    嘉兴市   5/17/2022  水产动物及其制品       餐饮服务业
# 2            1    否    否    女  27.0    嘉兴市   5/17/2022  水产动物及其制品       餐饮服务业
# 3            2    否    否    男  63.0    金华市  10/17/2023     肉与肉制品        家庭自制
# 4            3    否    否    女  22.0    温州市   6/10/2021     肉与肉制品       餐饮服务业
# ...        ...  ...  ...  ...   ...    ...         ...       ...         ...
# 564432  177055    否    否    男  26.0    衢州市   10/4/2022     乳与乳制品         预包装
# 564433  177056    否    否    女  40.0    丽水市   12/7/2022  水产动物及其制品          其他
# 564434  177057    否    否    男  49.0    丽水市  11/28/2022     乳与乳制品         预包装
# 564435  177058    否    否    男   4.0    丽水市  11/21/2022     蛋与蛋制品        家庭自制
# 564436  177059    否    否    男  60.0    丽水市  11/28/2022  水产动物及其制品  散装（包括简易包装）
#
# ...

# %%
from src.implement.xgboost_impl_classification import solve_data
df = solve_data(df)
df
# Out:
# c:\Users\AORUS\Desktop\program\food_disease_predict\src\implement\xgboost_impl_classification.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["鉴定结果大类"].fillna("/", inplace=True)
#           患者ID  是否复诊  是否住院  患者性别  患者年龄       发病日期  其他人是否发病  气候政策不确定性指数  \
# 0            1     0     0     0  27.0 2022-05-17        0    0.771001
# 1            1     0     0     0  27.0 2022-05-17        0    0.771001
# 2            1     0     0     0  27.0 2022-05-17        0    0.771001
# ...

# %%
df.keys()
# Out:
# Index([' 患者ID', '是否复诊', '是否住院', '患者性别', '患者年龄', '发病日期', '其他人是否发病',
#        '气候政策不确定性指数', '环保处罚案件数目', '经济核算-生产总值（亿元）', '农业-农、林、牧、渔业总产值（亿元）',
#        '农业-主要农产品产量-肉产量（吨）', '农业-主要农产品产量-禽蛋产量（吨）', '农业-主要农产品产量-牛奶产量（吨）',
#        '农业-水产品产量（万吨）', '农业-农村能源及农业物资消耗-农用塑料薄膜使用量（吨）',
#        '农业-农村能源及农业物资消耗-农用柴油使用量（吨）', '农业-农村能源及农业物资消耗-农用化肥施用量（折纯）（吨）',
#        '农业-农村能源及农业物资消耗-农药使用量（吨）', '文化、卫生和社会服务-文化和卫生-医院卫生院数（个）',
#        '文化、卫生和社会服务-文化和卫生-医生数（人）', '降水量', 'Temperature-before1day',
#        'Temperature-before2day', 'Temperature-before3day',
#        'Temperature-before4day', 'Temperature-before5day',
#        'Temperature-before6day', 'Temperature-before7day', 'sunlight', 'AQI',
#        '确诊食源性疾病', '食品分类_水产动物及其制品', '食品分类_油脂类', '食品分类_肉与肉制品', '食品分类_蛋与蛋制品',
#        '加工及包装方式_家庭自制', '加工及包装方式_散装（包括简易包装）', '加工及包装方式_预包装', '加工及包装方式_餐饮服务业',
#        '进食场所类型_农村宴席', '进食场所类型_学校', '进食场所类型_家庭', '进食场所类型_集体食堂', '进食场所类型_零售市场',
#        '进食场所类型_餐饮服务业'],
#       dtype='object')

# %% [markdown]
# # by case

# %%
from src.implement.xgboost_impl_classification import to_dataset,train
df = df.drop(columns=[' 患者ID', '发病日期'])

X_train, X_test, y_train, y_test = to_dataset(df)

model = train(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\AORUS\Desktop\program\food_disease_predict\fooddisease\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:55:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.888807206460965
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94     93243
#            1       0.07      0.19      0.10      3337
#
#     accuracy                           0.89     96580
#    macro avg       0.52      0.55      0.52     96580
# weighted avg       0.94      0.89      0.91     96580

# %%
from src.implement.xgboost_impl_classification import get_importance,plot_heap,plot_roc_auc

get_importance(model)
plot_heap(X_test, y_test,model)
plot_roc_auc(X_test, y_test,model)

# %% [markdown]
# # by human

# %%
from src.implement.xgboost_impl_classification import solve_data
df = pd.read_csv("data/final_data.csv",encoding="utf-8-sig")
df = solve_data(df)
df
# Out:
# c:\Users\AORUS\Desktop\program\food_disease_predict\src\implement\xgboost_impl_classification.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["鉴定结果大类"].fillna("/", inplace=True)
#           患者ID  是否复诊  是否住院  患者性别  患者年龄       发病日期  其他人是否发病  气候政策不确定性指数  \
# 0            1     0     0     0  27.0 2022-05-17        0    0.771001
# 1            1     0     0     0  27.0 2022-05-17        0    0.771001
# 2            1     0     0     0  27.0 2022-05-17        0    0.771001
# ...

# %%
df.keys()
# Out:
# Index([' 患者ID', '是否复诊', '是否住院', '患者性别', '患者年龄', '发病日期', '其他人是否发病',
#        '气候政策不确定性指数', '环保处罚案件数目', '经济核算-生产总值（亿元）', '农业-农、林、牧、渔业总产值（亿元）',
#        '农业-主要农产品产量-肉产量（吨）', '农业-主要农产品产量-禽蛋产量（吨）', '农业-主要农产品产量-牛奶产量（吨）',
#        '农业-水产品产量（万吨）', '农业-农村能源及农业物资消耗-农用塑料薄膜使用量（吨）',
#        '农业-农村能源及农业物资消耗-农用柴油使用量（吨）', '农业-农村能源及农业物资消耗-农用化肥施用量（折纯）（吨）',
#        '农业-农村能源及农业物资消耗-农药使用量（吨）', '文化、卫生和社会服务-文化和卫生-医院卫生院数（个）',
#        '文化、卫生和社会服务-文化和卫生-医生数（人）', '降水量', 'Temperature-before1day',
#        'Temperature-before2day', 'Temperature-before3day',
#        'Temperature-before4day', 'Temperature-before5day',
#        'Temperature-before6day', 'Temperature-before7day', 'sunlight', 'AQI',
#        '确诊食源性疾病', '食品分类_水产动物及其制品', '食品分类_油脂类', '食品分类_肉与肉制品', '食品分类_蛋与蛋制品',
#        '加工及包装方式_家庭自制', '加工及包装方式_散装（包括简易包装）', '加工及包装方式_预包装', '加工及包装方式_餐饮服务业',
#        '进食场所类型_农村宴席', '进食场所类型_学校', '进食场所类型_家庭', '进食场所类型_集体食堂', '进食场所类型_零售市场',
#        '进食场所类型_餐饮服务业'],
#       dtype='object')

# %%
df = df.sort_values("确诊食源性疾病",ascending=False)
df = df.drop_duplicates(subset=" 患者ID", keep="first")

# %%
from src.implement.xgboost_impl_classification import to_dataset,train
df = df.drop(columns=[' 患者ID', '发病日期'])

X_train, X_test, y_train, y_test = to_dataset(df)

model = train(X_train, X_test, y_train, y_test)
# Out:
# c:\Users\AORUS\Desktop\program\food_disease_predict\fooddisease\Lib\site-packages\xgboost\training.py:183: UserWarning: [17:55:18] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Accuracy: 0.8360819257880038
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91     26947
#            1       0.25      0.28      0.26      3129
#
#     accuracy                           0.84     30076
#    macro avg       0.58      0.59      0.58     30076
# weighted avg       0.85      0.84      0.84     30076

# %%
from src.implement.xgboost_impl_classification import get_importance,plot_heap,plot_roc_auc

get_importance(model)
plot_heap(X_test, y_test,model)
plot_roc_auc(X_test, y_test,model)
